# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read Data

# %%
file = pd.ExcelFile("../../../data/v4/Handballprojekt_1Liga fertig.xlsx")

file.sheet_names

df = file.parse('1. Liga')

# drop last col comments & favorite corner & empy rows at end
df = df.iloc[:, :-2]


df.replace('unklar', np.nan,inplace=True)
df.replace('unklar ', np.nan,inplace=True)
df.replace('fehlend', np.nan,inplace=True)
#df.dropna(inplace=True)
df.replace('-', np.nan,inplace=True)
df.columns = [ 'homeTeam','opponentTeam','day','name','playTime',
              'homeGoals','opponentGoals','throwSuccess','whistleThrowTime',
              'LRHandy','throwDirection','goalKeeperPosition',
              'goalKeeperName', 'goalKeeperHeightCM','shooterheightCM',
              'pressureSituation','noOfThrowsFromPlayer',
              'throwQuadrantLastThrow','lastThrowSuccess']
df = df.astype({'homeTeam':'string', 'opponentTeam':'string','day':'float16','name':'string','playTime':'float16',
              'homeGoals':'float16','opponentGoals':'float16','whistleThrowTime':'float16','goalKeeperPosition':'float16',
              'throwSuccess':'float16','LRHandy':'float16','throwDirection':'float16','pressureSituation':'float16','noOfThrowsFromPlayer':'float16',
              'throwQuadrantLastThrow':'float16','lastThrowSuccess':'float16','goalKeeperName':'string', 'goalKeeperHeightCM':'float16','shooterheightCM':'float16' })
df.head()

dfl1 = df.copy()
dfl1
# Out:
# /Users/nayansavaliya/Desktop/HandballGameAnalysis/hba-venv/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                homeTeam                   opponentTeam   day       name  \
# 0          SC Magdeburg             TVB 1898 Stuttgart   1.0  Magnusson
# 1          SC Magdeburg             TVB 1898 Stuttgart   1.0  Magnusson
# 2          SC Magdeburg             TVB 1898 Stuttgart   1.0  Magnusson
# 3          SC Magdeburg             TVB 1898 Stuttgart   1.0  Magnusson
# 4    Rhein-Neckar Löwen                   SC Magdeburg   2.0       <NA>
# ..                  ...                            ...   ...        ...
# 332            THW Kiel                  TuS N-Lübecke  31.0       <NA>
# 333            THW Kiel  Handball Sport Verein Hamburg  32.0    Eckberg
# 334            THW Kiel  Handball Sport Verein Hamburg  32.0    Eckberg
# 335  Rhein-Neckar Löwen                       THW Kiel  33.0    Eckberg
# 336            THW Kiel          FRISCH AUF! Göppingen  34.0       <NA>
#
#      playTime  homeGoals  opponentGoals  throwSuccess  whistleThrowTime  \
# 0        19.0        9.0            9.0           1.0              18.0
# 1        32.0       17.0           16.0           1.0              20.0
# 2        40.0       22.0           18.0           1.0              44.0
# 3        46.0       27.0           22.0           0.0              21.0
# 4         NaN        NaN            NaN           NaN               NaN
# ..        ...        ...            ...           ...               ...
# 332       NaN        NaN            NaN           NaN               NaN
# 333      11.0        4.0            1.0           0.0              42.0
# 334      47.0       24.0           14.0           1.0              59.0
# 335      44.0       21.0           22.0           1.0              35.0
# 336       NaN        NaN            NaN           NaN               NaN
#
#      LRHandy  throwDirection  goalKeeperPosition goalKeeperName  \
# 0        2.0             7.0                 1.0    Heinevetter
# 1        2.0             9.0                 1.0   Heinevedtter
# 2        2.0             8.0                 1.0        Vujovic
# 3        2.0             4.0                 1.0        Vujovic
# 4        NaN             NaN                 NaN           <NA>
# ..       ...             ...                 ...            ...
# 332      NaN             NaN                 NaN           <NA>
# 333      2.0             8.0                 1.0         Bitter
# 334      2.0             7.0                 1.0       Vortmann
# 335      2.0             9.0                 1.0        Birlehm
# 336      NaN             NaN                 NaN           <NA>
#
#      goalKeeperHeightCM  shooterheightCM  pressureSituation  \
# 0                 194.0            186.0                0.0
# 1                 194.0            186.0                0.0
# 2                 196.0            186.0                1.0
# 3                 196.0            186.0                0.0
# 4                   NaN              NaN                NaN
# ..                  ...              ...                ...
# 332                 NaN              NaN                NaN
# 333               205.0            191.0                0.0
# 334               195.0            191.0                2.0
# 335               196.0            191.0                0.0
# 336                 NaN              NaN                NaN
#
#      noOfThrowsFromPlayer  throwQuadrantLastThrow  lastThrowSuccess
# 0                     1.0                     NaN               NaN
# 1                     2.0                     7.0               1.0
# 2                     3.0                     9.0               1.0
# 3                     4.0                     8.0               1.0
# 4                     NaN                     NaN               NaN
# ..                    ...                     ...               ...
# 332                   NaN                     NaN               NaN
# 333                   1.0                     NaN               NaN
# 334                   2.0                     8.0               0.0
# 335                   1.0                     NaN               NaN
# 336                   NaN                     NaN               NaN
#
# [337 rows x 19 columns]

# %%
file = pd.ExcelFile("../../../data/v7/Handballprojekt_2Liga_14.01.2023.xlsx")

file.sheet_names

df = file.parse('2. Liga')

# drop last col comments & favorite corner & empy rows at end
df = df.iloc[:, :-2]


df.replace('unklar', np.nan,inplace=True)
df.replace('unklar ', np.nan,inplace=True)
df.replace('fehlend', np.nan,inplace=True)
#df.dropna(inplace=True)
df.replace('-', np.nan,inplace=True)
df.columns = [ 'homeTeam','opponentTeam','day','name','playTime',
              'homeGoals','opponentGoals','throwSuccess','whistleThrowTime',
              'LRHandy','throwDirection','goalKeeperPosition',
              'goalKeeperName', 'goalKeeperHeightCM','shooterheightCM',
              'pressureSituation','noOfThrowsFromPlayer',
              'throwQuadrantLastThrow','lastThrowSuccess']
df = df.astype({'homeTeam':'string', 'opponentTeam':'string','day':'float16','name':'string','playTime':'float16',
              'homeGoals':'float16','opponentGoals':'float16','whistleThrowTime':'float16','goalKeeperPosition':'float16',
              'throwSuccess':'float16','LRHandy':'float16','throwDirection':'float16','pressureSituation':'float16','noOfThrowsFromPlayer':'float16',
              'throwQuadrantLastThrow':'float16','lastThrowSuccess':'float16','goalKeeperName':'string', 'goalKeeperHeightCM':'float16','shooterheightCM':'float16' })
df.head()


dfl2 = df.copy()
dfl2
# Out:
#          homeTeam           opponentTeam   day          name  playTime  \
# 0         EHV Aue            TUSEM Essen   1.0    Noah Beyer      10.0
# 1         EHV Aue            TUSEM Essen   1.0    Noah Beyer      15.0
# 2         EHV Aue            TUSEM Essen   1.0    Noah Beyer      34.0
# 3         EHV Aue            TUSEM Essen   1.0    Noah Beyer      39.0
# 4         EHV Aue            TUSEM Essen   1.0    Noah Beyer      43.0
# ..            ...                    ...   ...           ...       ...
# 282  TV Emsdetten  Dessau-Roßlauer HV 06  35.0  Dirk Holzner       5.0
# 283  TV Emsdetten  Dessau-Roßlauer HV 06  35.0  Dirk Holzner       7.0
# 284  TV Emsdetten     ASV Hamm-Westfalen  36.0          <NA>       NaN
# 285       EHV Aue           TV Emsdetten  37.0          <NA>       NaN
# 286  TV Emsdetten     Eulen Ludwigshafen  38.0          <NA>       NaN
#
#      homeGoals  opponentGoals  throwSuccess  whistleThrowTime  LRHandy  \
# 0          5.0            3.0           1.0               NaN      1.0
# 1          8.0            4.0           1.0               NaN      1.0
# 2         15.0           14.0           0.0               NaN      1.0
# 3         18.0           17.0           1.0               NaN      1.0
# 4         19.0           19.0           1.0               NaN      1.0
# ..         ...            ...           ...               ...      ...
# 282        1.0            2.0           1.0              44.0      1.0
# 283        3.0            3.0           1.0              35.0      1.0
# 284        NaN            NaN           NaN               NaN      NaN
# 285        NaN            NaN           NaN               NaN      NaN
# 286        NaN            NaN           NaN               NaN      NaN
#
#      throwDirection  goalKeeperPosition goalKeeperName  goalKeeperHeightCM  \
# 0               3.0                 NaN       Bochmann               192.0
# 1               9.0                 NaN       Bochmann               192.0
# 2               2.0                 NaN      Petursson               185.0
# 3               8.0                 NaN      Petursson               185.0
# 4               7.0                 NaN      Petursson               185.0
# ..              ...                 ...            ...                 ...
# 282             1.0                 1.0          Malek               188.0
# 283             8.0                 1.0      Ambrosius               198.0
# 284             NaN                 NaN           <NA>                 NaN
# 285             NaN                 NaN           <NA>                 NaN
# 286             NaN                 NaN           <NA>                 NaN
#
#      shooterheightCM  pressureSituation  noOfThrowsFromPlayer  \
# 0              180.0                0.0                   1.0
# 1              180.0                0.0                   2.0
# 2              180.0                0.0                   3.0
# 3              180.0                2.0                   4.0
# 4              180.0                0.0                   5.0
# ..               ...                ...                   ...
# 282            180.0                0.0                   1.0
# 283            180.0                1.0                   2.0
# 284              NaN                NaN                   NaN
# 285              NaN                NaN                   NaN
# 286              NaN                NaN                   NaN
#
#      throwQuadrantLastThrow  lastThrowSuccess
# 0                       NaN               NaN
# 1                       3.0               1.0
# 2                       9.0               1.0
# 3                       2.0               2.0
# 4                       8.0               1.0
# ..                      ...               ...
# 282                     NaN               NaN
# 283                     1.0               1.0
# 284                     NaN               NaN
# 285                     NaN               NaN
# 286                     NaN               NaN
#
# [287 rows x 19 columns]

# %%
file = pd.ExcelFile("../../../data/v7/Handball 3. Liga vom 23.01.2023.xlsx")

file.sheet_names

df = file.parse('3. Liga')

# drop last col comments
df = df.iloc[:, :-1]
df.columns

df.replace('unklar', np.nan,inplace=True)
df.replace('unklar ', np.nan,inplace=True)
df.replace('fehlend', np.nan,inplace=True)
#df.dropna(inplace=True)
df.replace('-', np.nan,inplace=True)
df.columns =[ 'homeTeam','opponentTeam','day','name','playTime',
              'whistleThrowTime','homeGoals','opponentGoals','goalKeeperPosition',
              'throwSuccess','LRHandy','throwDirection','pressureSituation','noOfThrowsFromPlayer',
              'throwQuadrantLastThrow','lastThrowSuccess']
df = df.astype({'homeTeam':'string', 'opponentTeam':'string','day':'float16','name':'string','playTime':'float16',
              'homeGoals':'float16','opponentGoals':'float16','whistleThrowTime':'float16','goalKeeperPosition':'float16',
              'throwSuccess':'float16','LRHandy':'float16','throwDirection':'float16','pressureSituation':'float16','noOfThrowsFromPlayer':'float16',
              'throwQuadrantLastThrow':'float16','lastThrowSuccess':'float16' })


dfl3 = df.copy()
dfl3
# Out:
#                 homeTeam              opponentTeam   day     name  playTime  \
# 0           TV Emsdetten     ASV Hamm-Westfalen II   1.0     <NA>       NaN
# 1         HLZ Ahlener SG              TV Emsdetten   2.0     <NA>       NaN
# 2           TV Emsdetten              VfL Gladbeck   3.0  Holzner       2.0
# 3           TV Emsdetten              VfL Gladbeck   3.0  Holzner       7.0
# 4           TV Emsdetten              VfL Gladbeck   3.0  Holzner      31.0
# ..                   ...                       ...   ...      ...       ...
# 405      SC Magdeburg II                   EHV Aue  13.0      Lux      20.0
# 406              EHV Aue        SV Anhalt Bernburg  14.0     <NA>       NaN
# 407              EHV Aue  GSV Eintracht Braunatal   15.0      Lux       2.0
# 408              EHV Aue  GSV Eintracht Braunatal   15.0      Lux      26.0
# 409  HV Grün-Weiß Werder                   EHV Aue  16.0      Lux      48.0
#
#      whistleThrowTime  homeGoals  opponentGoals  goalKeeperPosition  \
# 0                 NaN        NaN            NaN                 NaN
# 1                 NaN        NaN            NaN                 NaN
# 2                23.0        0.0            0.0                 1.0
# 3                16.0        5.0            1.0                 1.0
# 4                28.0       19.0            9.0                 1.0
# ..                ...        ...            ...                 ...
# 405              36.0        6.0            9.0                 1.0
# 406               NaN        NaN            NaN                 NaN
# 407              40.0        0.0            0.0                 1.0
# 408              17.0       13.0           11.0                 1.0
# 409              25.0       21.0           29.0                 1.0
#
#      throwSuccess  LRHandy  throwDirection  pressureSituation  \
# 0             NaN      NaN             NaN                NaN
# 1             NaN      NaN             NaN                NaN
# 2             1.0      1.0             8.0                0.0
# 3             1.0      1.0             3.0                0.0
# 4             1.0      1.0             7.0                0.0
# ..            ...      ...             ...                ...
# 405           1.0      2.0             7.0                0.0
# 406           NaN      NaN             NaN                NaN
# 407           1.0      2.0             7.0                0.0
# 408           1.0      2.0             3.0                0.0
# 409           1.0      2.0             3.0                0.0
#
#      noOfThrowsFromPlayer  throwQuadrantLastThrow  lastThrowSuccess
# 0                     NaN                     NaN               NaN
# 1                     NaN                     NaN               NaN
# 2                     1.0                     NaN               1.0
# 3                     2.0                     8.0               1.0
# 4                     3.0                     3.0               1.0
# ..                    ...                     ...               ...
# 405                   1.0                     NaN               NaN
# 406                   NaN                     NaN               NaN
# 407                   1.0                     NaN               NaN
# 408                   2.0                     7.0               1.0
# 409                   1.0                     NaN               NaN
#
# [410 rows x 16 columns]

# %% [markdown]
# Combine

# %%
df = pd.concat([dfl1.loc[:,('throwSuccess','pressureSituation')].copy(),dfl2.loc[:,('throwSuccess','pressureSituation')].copy(),dfl3.loc[:,('throwSuccess','pressureSituation')].copy()])
#pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#      throwSuccess  pressureSituation
# 0             1.0                0.0
# 1             1.0                0.0
# 2             1.0                1.0
# 3             0.0                0.0
# 4             NaN                NaN
# ..            ...                ...
# 405           1.0                0.0
# 406           NaN                NaN
# 407           1.0                0.0
# 408           1.0                0.0
# 409           1.0                0.0
#
# [1034 rows x 2 columns]

# %% [markdown]
# General Summary

# %%
ps = df.loc[:,('throwSuccess','pressureSituation')].copy()
ps.dropna(inplace=True)
ps['throwSuccess'].replace(2.0, 1.0,inplace=True)
s = [0, 1,4,5,7]
ps = ps[ps.pressureSituation.isin(s) == True]
ps['pressureSituation'].replace(4.0, 1.0,inplace=True)
ps['pressureSituation'].replace(5.0, 1.0,inplace=True)
ps['pressureSituation'].replace(7.0, 1.0,inplace=True)
# print(ps)
# X_ps = ['No Pressure Situation','GoalKeeperChange','LastThrowFailed',
#      'GoalDiffLessEqualTo4After50MinPlay','GoalKeeperChange-LastThrowFailed',
#      'GoalKeeperChange-GoalDiffLessEqualTo4After50MinPlay','LastThrowFailed-GoalDiffLessEqualTo4After50MinPlay',
#      'GoalKeeperChange-LastThrowFailed-GoalDiffLessEqualTo4After50MinPlay',
#      'FirstInNachWurf']
# for i,s in enumerate(X_ps):
#     ps['pressureSituation'].replace(i, s,inplace=True)

# print(ps)
# ps1 =pd.DataFrame(ps.groupby('throwSuccess').pressureSituation.value_counts()).unstack()
# ps1
contigency= pd.crosstab(ps['throwSuccess'], ps['pressureSituation'], margins=True, margins_name="Total") 
contigency
# Out:
# pressureSituation  0.0  1.0  Total
# throwSuccess
# 0.0                111   22    133
# 1.0                519  130    649
# Total              630  152    782

# %%
#contigency_pct = pd.crosstab(ps['throwSuccess'], ps['pressureSituation'], normalize='all', margins=True, margins_name="Total")
dfpct = ps.copy()
dfpct['pressureSituation'].replace(0.0,'Same GoalKeeper',inplace=True)
dfpct['pressureSituation'].replace(1.0,'GoalKeeper Changed',inplace=True)
dfpct['throwSuccess'].replace(0.0,'Failed',inplace=True)
dfpct['throwSuccess'].replace(1.0,'Success',inplace=True)
contigency_pct = pd.crosstab(dfpct['pressureSituation'],dfpct['throwSuccess'], normalize='index')
contigency_pct.plot(kind='bar',stacked=False,color={"Failed": "red", "Success": "green"})
contigency_pct
# Out:
# throwSuccess          Failed   Success
# pressureSituation
# GoalKeeper Changed  0.144737  0.855263
# Same GoalKeeper     0.176190  0.823810

# %%
from scipy.stats import chi2_contingency


# null hypo : no significant association between pressure situation and throwsuccess
# research hypo : There is relation between pressure situation and throwsuccess
# for df=1 & alpha=0.05 c =3.84(Chi-square table)
contigencychi= pd.crosstab(ps['throwSuccess'], ps['pressureSituation']) 
c, p, dof, expected = chi2_contingency(contigencychi) 
print(c,p,dof)
print(expected)
#calculated c > 3.84  then reject Null Hypo
#  ->>>>>>>>>>>>>>>>> Null Hypo accepted with 5% error

# Also,
# P-value ≤ α: The variables have a statistically significant association (Reject H0)
# If the p-value is less than or equal to the significance level, you reject the null hypothesis and conclude that there is a statistically significant association between the variables.
# P-value > α: Cannot conclude that the variables are associated (Fail to reject H0)
# If the p-value is larger than the significance level, you fail to reject the null hypothesis because there is not enough evidence to conclude that the variables are associated.
# Out:
# 0.6499206256292428 0.4201410593848074 1
# [[107.1483376  25.8516624]
#  [522.8516624 126.1483376]]

# %% [markdown]
# Changing Goalkeeper increses the chances of Throw Success but as per Chi Square Test we can conclude that there is no statistically significant association between Throw Success and Pressure Situation with 5% error.
